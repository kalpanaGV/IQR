# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from uni import univariate
obj=univariate()
quan,qual=obj.QuanQual(dataset)
# Out:
# sl_no Quan
# gender Qual
# ssc_p Quan
# ssc_b Qual
# hsc_p Quan
# hsc_b Qual
# hsc_s Qual
# degree_p Quan
# degree_t Qual
# workex Qual
# etest_p Quan
# specialisation Qual
# mba_p Quan
# status Qual
# salary Quan

# %%
dataset["salary"]=dataset["salary"].fillna(0)

# %%
univ=obj.uniAnalysis(dataset,quan)

# %%
univ
# Out:
#               sl_no       ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# Mean          108.0   67.303395   66.333163  66.370186   72.100558  62.278186
# Median        108.0        67.0        65.0       66.0        71.0       62.0
# Mode              1        62.0        63.0       65.0        60.0       56.7
# 25th           54.5        60.6        60.9       61.0        60.0     57.945
# 50th          108.0        67.0        65.0       66.0        71.0       62.0
# 75th          161.5        75.7        73.0       72.0        83.5     66.255
# 99th         212.86        87.0       91.86      83.86        97.0    76.1142
# 100th         215.0        89.4        97.7       91.0        98.0      77.89
# IQR           107.0        15.1        12.1       11.0        23.5       8.31
# 1.5IQR        160.5       22.65       18.15       16.5       35.25     12.465
# Lesser       -106.0       37.95       42.75       44.5       24.75      45.48
# ...

# %%
univ["ssc_p"]["Lesser"]<univ["ssc_p"]["Min"]
# Out:
# True

# %%
lesser=[]
greater=[]

for columName in quan:
    if(univ[columName]["Lesser"]>univ[columName]["Min"]):
        lesser.append(columName)
    if(univ[columName]["Greater"]<univ[columName]["Max"]):
        greater.append(columName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
for lesscolumn in lesser:
    dataset[lesscolumn][dataset[lesscolumn]<univ[lesscolumn]["Lesser"]]=univ[lesscolumn]["Lesser"]
for greatercolum in greater:
    dataset[greatercolum][dataset[greatercolum]>univ[greatercolum]["Greater"]]=univ[greatercolum]["Greater"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7216\1946208385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[lesscolumn][dataset[lesscolumn]<univ[lesscolumn]["Lesser"]]=univ[lesscolumn]["Lesser"]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7216\1946208385.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[greatercolum][dataset[greatercolum]>univ[greatercolum]["Greater"]]=univ[greatercolum]["Greater"]

# %%
univ_after=obj.uniAnalysis(dataset,quan)

# %%
univ_after
# Out:
#               sl_no       ssc_p       hsc_p   degree_p     etest_p      mba_p  \
# Mean          108.0   67.303395   66.334744  66.358558   72.100558  62.278186
# Median        108.0        67.0        65.0       66.0        71.0       62.0
# Mode              1        62.0        63.0       65.0        60.0       56.7
# 25th           54.5        60.6        60.9       61.0        60.0     57.945
# 50th          108.0        67.0        65.0       66.0        71.0       62.0
# 75th          161.5        75.7        73.0       72.0        83.5     66.255
# 99th         212.86        87.0      91.129      83.86        97.0    76.1142
# 100th         215.0        89.4       91.15       88.5        98.0      77.89
# IQR           107.0        15.1        12.1       11.0        23.5       8.31
# 1.5IQR        160.5       22.65       18.15       16.5       35.25     12.465
# Lesser       -106.0       37.95       42.75       44.5       24.75      45.48
# ...

# %%
lesser=[]
greater=[]

for columName in quan:
    if(univ_after[columName]["Lesser"]>univ_after[columName]["Min"]):
        greater.append(columName)
    if(univ_after[columName]["Greater"]<univ_after[columName]["Max"]):
        greater.append(columName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
dataset.to_csv("Pre_processed_Placement.csv",index=False)

# %%
#skew<0--Negative --Mean
#skew>0--Postive--Mode
#skew=0--Normal--equal values
dataset.skew()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7216\1136595405.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.skew()
# sl_no       0.000000
# ssc_p      -0.132649
# hsc_p       0.162611
# degree_p    0.204164
# etest_p     0.282308
# mba_p       0.313576
# salary      0.125415
# dtype: float64

# %%
#kurtosis<3--PlatyKurtic
#Kurtosis>3 --Laptokurtic
#kurtosis=3 --mesokurtic
dataset.kurtosis()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7216\3460031871.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.kurtosis()
# sl_no      -1.200000
# ssc_p      -0.607510
# hsc_p       0.086901
# degree_p   -0.097490
# etest_p    -1.088580
# mba_p      -0.470723
# salary      0.025787
# dtype: float64

# %%
import seaborn as sns
sns.distplot(dataset["ssc_p"])
# Out:
# D:\SUGANTHI\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ssc_p', ylabel='Density'>

# %%
dataset["ssc_p"].std()
# Out:
# 10.827205398231452

# %%
dataset["ssc_p"].var()
# Out:
# 117.22837673549229
